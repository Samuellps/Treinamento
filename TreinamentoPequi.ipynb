# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuellps/Treinamento/blob/main/TreinamentoPequi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.6/780.6 kB 3.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="djEFqvndmNUXnLdlt13z")
project = rf.workspace("seat-detection").project("seat-detection-2zzxf")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.30, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Seat-Detection-2 in yolov8:: 100%|██████████| 10634/10634 [00:01<00:00, 6193.36it/s]

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data=/content/Seat-Detection-2/data.yaml \
epochs=40 \
imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 168MB/s]
# Ultralytics YOLOv8.2.30 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model=/content/runs/detect/train/weights/best.pt source=/content/WIN_20240610_12_57_16_Pro.jpg imgsz=320
# Out:
# Ultralytics YOLOv8.2.30 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/WIN_20240610_12_57_16_Pro.jpg: 192x320 1 emptychair, 105.2ms
# Speed: 1.0ms preprocess, 105.2ms inference, 611.6ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
